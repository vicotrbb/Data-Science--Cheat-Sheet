# %% [markdown]
# <a href="https://colab.research.google.com/github/vicotrbb/Data-Science--Cheat-Sheet/blob/master/image_classification/pneumonia_detection/pneumonia_classification_idea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classificacao de imagens de raios-x para deteccao de pneumonia
#
# Ideia baseada em um dataset encontrado no kagle: https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia
#
# ## Objetivo
#
# Ser capaz de classificar imagens de raios-x dos pulmoes de pacientes e identificar a existencia de pneumonia.
# Este notebook tem o objetivo de servir como repositorio de dados para o projeto, servindo como plataforma de testes, pesquisa e observacoes/anotacoes
#
# ## Tecnologias
#
# to be described
#
# ## Autores
#
# Victor Bona - https://github.com/vicotrbb

# %% [markdown]
# # Fontes, documentacoes e links
#
# *   Dataset: https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia
# *
